# %% [markdown]
# ## Merge files

# %%
#imports
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Google merge and cleaning

# %%
#read test data from Google scraping
ny_goog = pd.read_csv("ny_goog.csv")
ca_goog = pd.read_csv("ca_goog.csv")
ch_goog = pd.read_csv("ch_goog.csv")
zagat = pd.read_csv("dc_google_zagat.csv")
post = pd.read_csv("post_goog.csv")

# %%
us_goog = pd.concat([ny_goog,ca_goog,ch_goog])
dc = pd.concat([zagat,post])

# %%
us_goog = us_goog.reset_index(drop=True)
dc = dc.reset_index(drop=True)

# %%
#drop description for this part
dc.drop("desc",axis=1,inplace=True)

# %%
us_goog = us_goog.applymap(lambda x: np.nan if x=="None" else x)
dc = dc.applymap(lambda x: np.nan if x=="None" else x)
#post = post.applymap(lambda x: np.nan if x=="None" else x)

# %%
#now check null values
us_goog.isnull().sum()
# Out:
# name      17
# rev      113
# price     76
# dtype: int64

# %%
dc.isnull().sum()
# Out:
# name     78
# price    90
# rev      91
# dtype: int64

# %%
post.isnull().sum()
# Out:
# name     0
# rev      0
# price    0
# dtype: int64

# %%
#drop them
us_goog.dropna(inplace=True)
dc.dropna(inplace=True)
#post.dropna(inplace=True)

# %%
#let's clean the names
def cleanName(x):
    x = str(x).replace("\n", "")
    if x[-17:].lower()=='websitedirections':
        return x[:-17]
    else:
        return x

# %%
us_goog["name"] = us_goog["name"].apply(cleanName)
dc["name"] = dc["name"].apply(cleanName)
#post["name"] = post["name"].apply(cleanName)

# %%
#separate rev 
us_goog["rating"] = us_goog["rev"].apply(lambda x: x.split("\n")[0])
dc["rating"] = dc["rev"].apply(lambda x: x.split("\n")[0])
#post["rating"] = post["rev"].apply(lambda x: x.split("\n")[0])

# %%
#get the reviews if available
def getReviews(x):
    try:
        return x.split("\n")[1]
    except:
        return np.nan

# %%
us_goog["numrev"] = us_goog["rev"].apply(getReviews)
us_goog.dropna(inplace=True)

dc["numrev"] = dc["rev"].apply(getReviews)
dc.dropna(inplace=True)

# post["numrev"] = post["rev"].apply(getReviews)
# post.dropna(inplace=True)

# %%
#let's split up the price to price and cuisine
def getPrice(x):
    price = x.split("·")[0]
    if price[0] == "$":
        return price.replace(" ","")
    else:
        return np.nan

# %%
us_goog["goog_price"] = us_goog["price"].apply(getPrice)
us_goog.dropna(inplace=True)

dc["goog_price"] = dc["price"].apply(getPrice)
dc.dropna(inplace=True)

# post["goog_price"] = post["price"].apply(getPrice)
# post.dropna(inplace=True)

# %%
def getCuisine(x):
    try:
        cuisine = x.split("·")[1]
        if cuisine[0] != "$":
            if "Restaurant" in cuisine:
                return cuisine.replace("Restaurant","")
            else:
                return cuisine
        else:
            if x.split("·")[0][0] != "$": 
                return x.split("·")[0].replace("Restaurant","")
    except:
        return np.nan

# %%
us_goog["cuisine"] = us_goog["price"].apply(getCuisine)
us_goog.dropna(inplace=True)

dc["cuisine"] = dc["price"].apply(getCuisine)
dc.dropna(inplace=True)

# post["cuisine"] = post["price"].apply(getCuisine)
# post.dropna(inplace=True)

# %%
def cleanReviews(x):
    if re.findall(r"\d",x):
        return "".join(re.findall(r"\d",x))
    else:
        return np.nan

# %%
us_goog.numrev = us_goog["numrev"].apply(cleanReviews)
us_goog.dropna(inplace=True)

dc.numrev = dc["numrev"].apply(cleanReviews)
dc.dropna(inplace=True)

# post.numrev = post["numrev"].apply(cleanReviews)
# post.dropna(inplace=True)

# %%
us_goog.drop(["rev","price"],axis=1,inplace=True)
dc.drop(["rev","price"],axis=1,inplace=True)
#post.drop(["rev","price"],axis=1,inplace=True)

# %%
#save clean test data
us_goog.to_csv("us_goog.csv",encoding="utf-8",index=False)
dc.to_csv("dc_test.csv",encoding="utf-8",index=False)
# post.to_csv("post_test.csv",encoding="utf-8",index=False)

# %%
us_goog
# Out:
#                            name rating numrev goog_price          cuisine
# 0                Noodle Pudding    4.3    118         $$        Italian
# 1       Peter Luger Steak House    4.2    910       $$$$     Steak House
# 2                         Vic's    4.1     43         $$   Mediterranean
# 3                        Gnocco    3.9     72         $$           Pizza
# 4                        Hasaki    4.2     63         $$        Japanese
# 5                        Hearth    4.2    102        $$$     Fine Dining
# 6                      Kanoyama    4.1     88         $$        Japanese
# 8                       Soba-ya    4.1    193         $$        Japanese
# 9                    Da Umberto    4.4     41        $$$         Italian
# 10           Rocking Horse Cafe    4.0    137         $$         Mexican
# 11                      Paradou    3.4     97        $$$          French
# 12                       Annisa    4.5     88       $$$$        American
# 13                       BONDST    4.2    131        $$$        Japanese
# 14         Gotham Bar and Grill    4.5    377       $$$$        American
# 15                     Le Gigot    4.4     43         $$          French
# 16                         Lupa    4.2    261        $$$         Italian
# 17             Pearl Oyster Bar    4.3    136        $$$         Seafood
# 18                      Hangawi    4.3    183        $$$          Korean
# 19               Phoenix Garden    3.7     51         $$         Chinese
# 21                   IL Cortile    3.9    117        $$$         Italian
# 22                Dim Sum Go Go    3.7    174         $$         Chinese
# 23            Peking Duck House    3.8    210         $$         Chinese
# 24                     Thai Son    4.1    121         $$      Vietnamese
# 25     Babbo Ristorante Enoteca    4.2    487       $$$$         Italian
# 26                       Crispo    4.0    141        $$$         Italian
# 27             Mary's Fish Camp    4.1    107         $$         Seafood
# 28                           Po    4.2     86        $$$         Italian
# 29     Sevilla Restaurant & Bar    4.2     87         $$         Spanish
# 30        MarkJoseph Steakhouse    4.5     90        $$$      Steak House
# 31          Nebraska Steakhouse    4.0     15        $$$      Steak House
# ...                         ...    ...    ...        ...              ...
# 1559  Luella's Southern Kitchen    4.3     76          $   Southern  (US)
# 1560                   La Plena    4.3     28          $    Puerto Rican
# 1561          The Franklin Room    4.8     56         $$        American
# 1562             The Promontory    4.2    142        $$$        American
# 1563              Rural Society    4.2     14        $$$     Argentinian
# 1564                Les Nomades    4.5     31       $$$$          French
# 1565              Mana Food Bar    4.5    113         $$      Vegetarian
# 1566         Mercat a la Planxa    4.0    162        $$$         Spanish
# 1567                         mk    4.5     88        $$$    New American
# 1568             Paramount Room    4.1     70         $$              Bar
# 1569  Pho Xe Tang - Tank Noodle    4.2    248         $$      Vietnamese
# 1570                 Ras Dashen    4.2     94         $$       Ethiopian
# 1571                       Riva    3.6    102        $$$         Seafood
# 1572                The Rosebud    4.4    130         $$         Italian
# 1574                      Schwa    4.6     51       $$$$    New American
# 1575              Spacca Napoli    4.6    196         $$           Pizza
# 1576                Topolobampo    4.3    155        $$$         Mexican
# 1577                        Tru    4.4     91       $$$$          French
# 1578                 North Pond    4.4     66        $$$        American
# 1579                    Everest    4.3     80       $$$$          French
# 1580                 La Sardine    4.5     40         $$          French
# 1581                   Spiaggia    4.3    104       $$$$         Italian
# 1582               Mon Ami Gabi    4.4     69         $$          French
# 1583                    Paprika    3.6     23         $$      Vegetarian
# 1585  Bavette's Bar &amp; Boeuf    4.6    128        $$$      Steak House
# 1586              Tortoise Club    4.1     41        $$$        American
# 1587                   Travelle    4.2     18        $$$        American
# 1588                Staropolska    4.6     87         $$          Polish
# 1589                  Charlatan    4.2     29         $$         Italian
# 1590               The Duck Inn    4.2     44         $$        American
#
# [1315 rows x 5 columns]

# %% [markdown]
# ### Michelin and Google Merge

# %%
michelin = pd.read_csv("combined_clean.csv")

# %%
#let's get the US data only
def findCountry(x):
    if re.search("[9]{1}[0-9]{4}",x[-5:]):
        return "CA"
    elif re.search("[1]{1}[0-9]{4}",x[-5:]):
        return "NY"
    elif re.search("[6]{1}[0-9]{4}",x[-5:]):
        return "IL"
    else:
        return "NA"

# %%
michelin["state"] = michelin["address"].apply(findCountry)

# %%
us = michelin[(michelin["state"]=="NY")|(michelin["state"]=="CA")|(michelin["state"]=="IL")]

# %%
#merge on name keep left (michelin restaurants)
us_mg = us.merge(us_goog,how="left",on="name")

# %%
#drop nulls and reset index
us_mg.dropna(inplace=True)
us_mg.reset_index(drop=True,inplace=True)

# %%
#change the price to numeric instead of $$$$
us_mg.goog_price = us_mg.goog_price.map({"$":1,"$$":2,"$$$":3,"$$$$":4})
dc["goog_price"] = dc.goog_price.map({"$":1,"$$":2,"$$$":3,"$$$$":4})
#post["goog_price"] = post.goog_price.map({"$":1,"$$":2,"$$$":3,"$$$$":4})

# %%
def generalizeC(x):
    cuisines = {"Chinese":["dim","dimsum","sichuan","taiwanese","tea","teahouse","mandarin"],
                "Mexican":["taco"],"International":["eclectic"],"Latin American":["nuevo"],
                "Japanese":["sushi","ramen","yakitori"],
                "American":["diner","family","hamburger","cafe","newamerican","traditionalamerican"],
               "Steakhouse":["steakhouse"],
               "Contemporary":["finedining"],
               "Spanish":["tapasbar"]}
    
    y = x.replace(" ","").lower()
    for key,val in cuisines.iteritems():
        if y in val:
            return key
    return x

# %%
us_mg.cuisine = us_mg.cuisine.apply(generalizeC)
dc.cuisine = dc.cuisine.apply(generalizeC)
#post.cuisine = post.cuisine.apply(generalizeC)

# %%
def cleanCuisine(x):
    x = re.sub(r"^\s*", "", x)
    x = re.sub(r"\s*$","",x)
    
    if x != "":
        return x
    else:
        return np.nan

# %%
us_mg["cuisine"] = us_mg["cuisine"].apply(cleanCuisine)
us_mg.dropna(inplace=True)

dc["cuisine"] = dc["cuisine"].apply(cleanCuisine)
dc.dropna(inplace=True)

# post["cuisine"] = post["cuisine"].apply(cleanCuisine)
# post.dropna(inplace=True)

# %%
us_mg.numrev = pd.to_numeric(us_mg.numrev)
us_mg.rating = pd.to_numeric(us_mg.rating)

dc.numrev = pd.to_numeric(dc.numrev)
dc.rating = pd.to_numeric(dc.rating)

# post.numrev = pd.to_numeric(post.numrev)
# post.rating = pd.to_numeric(post.rating)

# %%
us_mg.stars.value_counts()
# Out:
# 0.0    891
# 1.0    144
# 2.0     24
# 3.0     18
# Name: stars, dtype: int64

# %%
us_mg["bstars"] = us_mg.stars.map({0.0:0,1.0:1,2.0:1,3.0:1})
us_mg["cstars"] = us_mg.stars.map({0.0:0,1.0:1,2.0:2,3.0:2})

# %%
price_cuisine = pd.DataFrame(us_mg.groupby(["cuisine","goog_price"]).usd_avg.median())
avgPrice = pd.DataFrame(us_mg.groupby("goog_price").usd_avg.median())

# %%
price_cuisine
# Out:
#                             usd_avg
# cuisine         goog_price
# Afghani         2             37.00
# African         2             18.50
# American        1             37.00
#                 2             37.00
#                 3             37.00
#                 4            112.50
# Argentinian     3             37.00
# Asian           1             37.00
#                 2             37.00
#                 3             37.00
# Asian Fusion    1             18.50
#                 2             27.75
#                 3             37.00
# Australian      2             37.00
# Austrian        2             37.00
#                 3             49.50
# Bangladeshi     1             18.50
# Bar             2             37.00
#                 3             37.00
#                 4            112.50
# Bar & Grill     2             27.75
#                 3             37.00
#                 4             62.00
# Barbecue        1             27.75
#                 2             37.00
# Basque          2             18.50
#                 3             37.00
# Belgian         3             37.00
# Bistro          2             37.00
#                 3             37.00
# ...                             ...
# Scandinavian    4            112.50
# Seafood         2             37.00
#                 3             37.00
#                 4            112.50
# Shanghainese    2             18.50
# Small Plates    2             37.00
# Soul Food       1             37.00
#                 2             18.50
# Southeast Asian 1             18.50
#                 2             18.50
# Southern  (US)  1             37.00
#                 2             37.00
# Spanish         2             37.00
#                 3             37.00
# Steakhouse      2             37.00
#                 3             62.00
#                 4            112.50
# Tapas           2             37.00
#                 3             37.00
# Thai            1             18.50
#                 2             37.00
#                 3             37.00
#                 4            112.50
# Turkish         2             37.00
# Vegetarian      2             18.50
#                 3             37.00
# Vietnamese      1             37.00
#                 2             18.50
#                 3             49.50
# Wine Bar        2             37.00
#
# [167 rows x 1 columns]

# %%
ap = avgPrice.to_dict()
pc = price_cuisine.to_dict()

# %%
pc
# Out:
# {'usd_avg': {('Afghani', 2): 37.0,
#   ('African', 2): 18.5,
#   ('American', 1): 37.0,
#   ('American', 2): 37.0,
#   ('American', 3): 37.0,
#   ('American', 4): 112.5,
#   ('Argentinian', 3): 37.0,
#   ('Asian', 1): 37.0,
#   ('Asian', 2): 37.0,
#   ('Asian', 3): 37.0,
#   ('Asian Fusion', 1): 18.5,
#   ('Asian Fusion', 2): 27.75,
#   ('Asian Fusion', 3): 37.0,
#   ('Australian', 2): 37.0,
#   ('Austrian', 2): 37.0,
#   ('Austrian', 3): 49.5,
#   ('Bangladeshi', 1): 18.5,
#   ('Bar', 2): 37.0,
#   ('Bar', 3): 37.0,
#   ('Bar', 4): 112.5,
#   ('Bar & Grill', 2): 27.75,
#   ('Bar & Grill', 3): 37.0,
#   ('Bar & Grill', 4): 62.0,
#   ('Barbecue', 1): 27.75,
#   ('Barbecue', 2): 37.0,
#   ('Basque', 2): 18.5,
#   ('Basque', 3): 37.0,
#   ('Belgian', 3): 37.0,
#   ('Bistro', 2): 37.0,
#   ('Bistro', 3): 37.0,
#   ('Brazilian', 2): 37.0,
#   ('Brazilian', 3): 62.0,
#   ('Breakfast', 2): 18.5,
#   ('British', 2): 37.0,
#   ('British', 3): 62.0,
#   ('Brunch', 2): 37.0,
#   ('Brunch', 3): 37.0,
#   ('Burmese', 2): 18.5,
#   ('Cajun', 2): 37.0,
#   ('Californian', 2): 37.0,
#   ('Californian', 3): 62.0,
#   ('Californian', 4): 62.0,
#   ('Cambodian', 2): 18.5,
#   ('Caribbean', 1): 37.0,
#   ('Caribbean', 2): 27.75,
#   ('Chicken', 1): 37.0,
#   ('Chinese', 1): 18.5,
#   ('Chinese', 2): 37.0,
#   ('Chinese', 3): 112.5,
#   ('Chinese', 4): 112.5,
#   ('Cocktail Bar', 2): 37.0,
#   ('Contemporary', 3): 87.25,
#   ('Contemporary', 4): 112.5,
#   ('Deli', 2): 18.5,
#   ('Dessert', 2): 37.0,
#   ('Dumpling', 1): 18.5,
#   ('Dutch', 2): 37.0,
#   ('Ethiopian', 2): 37.0,
#   ('European', 2): 37.0,
#   ('European', 3): 37.0,
#   ('European', 4): 62.0,
#   ('French', 2): 37.0,
#   ('French', 3): 37.0,
#   ('French', 4): 112.5,
#   ('Gastropub', 2): 37.0,
#   ('Gastropub', 3): 37.0,
#   ('Georgian', 2): 27.75,
#   ('German', 2): 37.0,
#   ('Greek', 2): 37.0,
#   ('Greek', 3): 37.0,
#   ('Greek', 4): 37.0,
#   ('Hawaiian', 2): 37.0,
#   ('Indian', 2): 37.0,
#   ('Indian', 3): 37.0,
#   ('Indonesian', 1): 18.5,
#   ('International', 2): 37.0,
#   ('International', 3): 37.0,
#   ('International', 4): 87.25,
#   ('Italian', 2): 37.0,
#   ('Italian', 3): 37.0,
#   ('Italian', 4): 112.5,
#   ('Japanese', 1): 18.5,
#   ('Japanese', 2): 37.0,
#   ('Japanese', 3): 62.0,
#   ('Japanese', 4): 112.5,
#   ('Japanese Steakhouse', 2): 62.0,
#   ('Jewish', 2): 37.0,
#   ('Korean', 1): 18.5,
#   ('Korean', 2): 37.0,
#   ('Korean', 3): 37.0,
#   ('Korean', 4): 112.5,
#   ('Korean Barbecue', 2): 37.0,
#   ('Korean Barbecue', 3): 37.0,
#   ('Kosher', 1): 18.5,
#   ('Laotian', 2): 37.0,
#   ('Latin American', 1): 18.5,
#   ('Latin American', 2): 37.0,
#   ('Malaysian', 1): 18.5,
#   ('Malaysian', 2): 37.0,
#   ('Mediterranean', 2): 37.0,
#   ('Mediterranean', 3): 37.0,
#   ('Mexican', 1): 18.5,
#   ('Mexican', 2): 37.0,
#   ('Mexican', 3): 37.0,
#   ('Mexican', 4): 112.5,
#   ('Middle Eastern', 1): 37.0,
#   ('Middle Eastern', 2): 37.0,
#   ('Modern European', 3): 62.0,
#   ('Modern French', 3): 112.5,
#   ('Moroccan', 2): 18.5,
#   ('Moroccan', 3): 62.0,
#   ('Moroccan', 4): 62.0,
#   ('Neapolitan', 2): 37.0,
#   ('Neapolitan', 3): 62.0,
#   ('New Zealand', 2): 62.0,
#   ('Northern Italian', 2): 37.0,
#   ('Northern Italian', 3): 62.0,
#   ('Nuevo Latino', 2): 37.0,
#   ('Nuevo Latino', 3): 37.0,
#   ('Oyster Bar', 3): 37.0,
#   ('Pan-Asian', 3): 37.0,
#   ('Pan-Latin', 2): 37.0,
#   ('Pasta Shop', 2): 37.0,
#   ('Persian', 2): 18.5,
#   ('Peruvian', 2): 37.0,
#   ('Peruvian', 3): 37.0,
#   ('Pizza', 1): 18.5,
#   ('Pizza', 2): 37.0,
#   ('Pizza', 3): 37.0,
#   ('Pizza Delivery', 2): 37.0,
#   ('Polish', 2): 18.5,
#   ('Portuguese', 3): 49.5,
#   ('Pub', 2): 37.0,
#   ('Puerto Rican', 1): 18.5,
#   ('Russian', 3): 37.0,
#   ('Sandwich Shop', 1): 18.5,
#   ('Scandinavian', 1): 112.5,
#   ('Scandinavian', 4): 112.5,
#   ('Seafood', 2): 37.0,
#   ('Seafood', 3): 37.0,
#   ('Seafood', 4): 112.5,
#   ('Shanghainese', 2): 18.5,
#   ('Small Plates', 2): 37.0,
#   ('Soul Food', 1): 37.0,
#   ('Soul Food', 2): 18.5,
#   ('Southeast Asian', 1): 18.5,
#   ('Southeast Asian', 2): 18.5,
#   ('Southern  (US)', 1): 37.0,
#   ('Southern  (US)', 2): 37.0,
#   ('Spanish', 2): 37.0,
#   ('Spanish', 3): 37.0,
#   ('Steakhouse', 2): 37.0,
#   ('Steakhouse', 3): 62.0,
#   ('Steakhouse', 4): 112.5,
#   ('Tapas', 2): 37.0,
#   ('Tapas', 3): 37.0,
#   ('Thai', 1): 18.5,
#   ('Thai', 2): 37.0,
#   ('Thai', 3): 37.0,
#   ('Thai', 4): 112.5,
#   ('Turkish', 2): 37.0,
#   ('Vegetarian', 2): 18.5,
#   ('Vegetarian', 3): 37.0,
#   ('Vietnamese', 1): 37.0,
#   ('Vietnamese', 2): 18.5,
#   ('Vietnamese', 3): 49.5,
#   ('Wine Bar', 2): 37.0}}

# %%
def getAvgPriceByCuisine(x,y):
    xy = (x,y)
    
    try:
        return pc["usd_avg"][xy]
    except:
        return ap["usd_avg"][y]

# %%
us_mg["pc"] = np.vectorize(getAvgPriceByCuisine)(us_mg["cuisine"],us_mg["goog_price"])
dc["pc"] = np.vectorize(getAvgPriceByCuisine)(dc["cuisine"],dc["goog_price"])
#post["pc"]= np.vectorize(getAvgPriceByCuisine)(post["cuisine"],post["goog_price"])

# %%
us_mg.dropna(inplace=True)
dc.dropna(inplace=True)
#post.dropna(inplace=True)

# %%
us_mg.drop_duplicates(inplace=True)
dc.drop_duplicates(inplace=True)
#post.drop_duplicates(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(list(us_mg["cuisine"].values) + list(dc["cuisine"].values))

# le = LabelEncoder()
# le.fit(list(us_mg["cuisine"].values) + list(post["cuisine"].values))
# Out:
# LabelEncoder()

# %%
us_mg["cuisine"] = le.transform(us_mg["cuisine"].values)
dc["cuisine"] = le.transform(dc["cuisine"].values)

# us_mg["cuisine"] = le.transform(us_mg["cuisine"].values)
# post["cuisine"] = le.transform(post["cuisine"].values)

# %%
#save again
us_mg.to_csv("us_mg.csv",encoding="utf-8",index=False)
dc.to_csv("dc_test.csv",encoding="utf-8",index=False)
#post.to_csv("post_test.csv",encoding="utf-8",index=False)

# %% [markdown]
# ## Modeling

# %%
from sklearn.cross_validation import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,auc
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, GradientBoostingClassifier

# %%
X = us_mg[["rating","numrev","pc","cuisine"]]
y = us_mg["cstars"]

# %%
X_scaled = preprocessing.scale(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,test_size=0.4)

# %%
baseline = y.value_counts()/len(y)
baseline
# Out:
# 0    0.860520
# 1    0.106383
# 2    0.033097
# Name: cstars, dtype: float64

# %%
cv = StratifiedKFold(y, n_folds=5,shuffle=True)

# %%
def score(model, name, myX,myy):
    s = cross_val_score(model, myX, myy, cv=cv)
    print "{} Score:\t{:0.3} ± {:0.3}".format(name, s.mean().round(3), s.std().round(3))

# %%
def fitAndPrint(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print confusion_matrix(y_test,y_pred)

# %%
lm = LogisticRegression()

# %%
score(lm,"Logistic Regression",X_scaled,y)
# Out:
# Logistic Regression Score:	0.881 ± 0.019

# %%
fitAndPrint(lm)
# Out:
# [[281   7   0]
#  [ 25  13   0]
#  [  1  12   0]]

# %%
X_dc = dc[["rating","numrev","pc","cuisine"]]
X_scaled_dc = preprocessing.scale(X_dc)

# %%
y_pred = lm.predict(X_scaled_dc)

# %%
count=0
for a,b in zip(dc["name"].values,y_pred):
    if b>=1:
        print a,b
# Out:
# Corduroy 1
# Fogo de Chão Brazilian Steakhouse 1
# Minibar 1
# The Lafayette 1
# Marcel's 1
# Plume 1
# Equinox 1
# Obelisk 1
# The Capital Grille 1
# Sakedokoro Makoto 1
# Matisse 1
# Equinox 1
# Marcel’s 1

# %%
dt = DecisionTreeClassifier(class_weight="balanced")

# %%
score(dt,"Decision Tree",X_scaled,y)
# Out:
# Decision Tree Score:	0.844 ± 0.015

# %%
fitAndPrint(dt)
# Out:
# [[266  26   3]
#  [ 21  10   3]
#  [  1   4   5]]

# %%
dt.fit(X_scaled,y)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions_dt = dt.predict(X_scaled_dc)

# %%
for a,b in zip(dc["name"].values,predictions_dt):
    if b>=1:
        print a,b
# Out:
# Corduroy 1
# Fogo de Chão Brazilian Steakhouse 1
# Minibar 1
# The Lafayette 2
# Marcel's 2
# SEI 1
# BlackSalt 1
# Oceanaire Seafood Room (DC) 1
# Blue Duck Tavern 1
# Restaurant Nora 1
# BLT Steak 1
# 1789 Restaurant 1
# Equinox 1
# Obelisk 1
# The Capital Grille 2
# Bistrot Lepic & Wine Bar 1
# Beuchert’s Saloon 1
# Toro Toro 1
# La Chaumiere 1
# Flight Wine Bar 1
# Charlie Palmer Steak 1
# Al Dente Italian Restaurant D.C. 1
# Mari Vanna DC 1
# DC Coast 1
# DGS Delicatessen 1
# Room 11 1
# Buck's Fishing & Camping 1
# Matisse 2
# Bearnaise 1
# Jack Rose Dining Saloon 1
# Pesce 1
# Equinox 1
# Masseria 1
# Marcel’s 2

# %%
rf = RandomForestClassifier(class_weight="balanced")

# %%
score(rf,"Random Forest",X_scaled,y)
# Out:
# Random Forest Score:	0.866 ± 0.01

# %%
fitAndPrint(rf)
# Out:
# [[285   6   4]
#  [ 20  10   4]
#  [  4   2   4]]

# %%
for a,b in zip(X.columns.tolist(), rf.feature_importances_):
    print a, b
# Out:
# goog_price 0.182294313169
# rating 0.149111562989
# numrev 0.297420914428
# pc 0.220458599752
# cuisine 0.150714609663

# %%
rf.fit(X_scaled,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predictions = rf.predict(X_scaled_dc)

# %%
count=0
for a,b in zip(dc["name"].values,predictions):
    if b>=1:
        print a,b
# Out:
# Minibar 1
# Marcel's 1
# 1789 Restaurant 1
# Beuchert’s Saloon 1
# Toro Toro 1
# Charlie Palmer Steak 1
# DC Coast 1
# Meridian Pint 1
# Matisse 1
# Garrison 1
# Marcel’s 1

# %%
ada = AdaBoostClassifier()

# %%
score(ada,"Adaptive Boosting",X_scaled,y)
# Out:
# Adaptive Boosting Score:	0.819 ± 0.054

# %%
fitAndPrint(ada)
# Out:
# [[272  19   4]
#  [ 23   9   2]
#  [  5   4   1]]

# %%
predictions = ada.predict(X_scaled_dc)

# %%
count=0
for a,b in zip(dc["name"].values,predictions):
    if b>=1:
        print a,b
        count+=1
print count
# Out:
# Minibar 2
# The Lafayette 1
# Zaytinya 1
# Marcel's 1
# Plume 2
# Joe's Seafood, Prime Steak & Stone Crab 1
# Restaurant Nora 1
# G by Mike Isabella 1
# Equinox 1
# Obelisk 2
# 2 Amys 1
# 7th Hill Pizza - Palisades 1
# Legal Sea Foods 1
# Campono 1
# Doi Moi 1
# Eat the Rich 1
# Hank's Oyster Bar 1
# Oyamel Cocina Mexicana 1
# Jaleo 1
# La Chaumiere 1
# Flight Wine Bar 1
# TaKorean | The Yards DC 1
# Al Dente Italian Restaurant D.C. 1
# Lebanese Taverna - DC 1
# Pi Pizzeria - DC 1
# Luke's Lobster Penn Quarter 1
# Red Apron Butcher 1
# Horace & Dickie's Seafood 1
# Southern Efficiency 1
# DGS Delicatessen 1
# Tacos El Chilango 1
# Boundary Road 1
# WE, THE PIZZA 1
# Pizzeria Paradiso 1
# Dino's Grotto 1
# Buck's Fishing & Camping 1
# Matisse 1
# Senart's Oyster & Chop House 1
# Bearnaise 1
# Soupergirl 1
# Martin's Tavern 1
# Boss Shepherd's Restaurant 1
# 2Amys 1
# Zaytinya 1
# Hank’s Oyster Bar 1
# Crane & Turtle 1
# Centrolina 1
# Equinox 1
# Masseria 1
# Marcel’s 1
# 50

# %%
gb = GradientBoostingClassifier()

# %%
score(gb,"Gradient Boosting",X_scaled,y)
# Out:
# Gradient Boosting Score:	0.876 ± 0.02

# %%
fitAndPrint(gb)
# Out:
# [[285   7   3]
#  [ 21  11   2]
#  [  3   3   4]]

# %%
predictions = gb.predict(X_scaled_dc)

# %%
count=0
for a,b in zip(dc["name"].values,predictions):
    if b>=1:
        print a,b
# Out:
# The Lafayette 2
# Marcel's 1
# Plume 2
# The Oval Room 1
# Al Tiramisu 1
# Komi 1
# Blue Duck Tavern 1
# 1789 Restaurant 1
# Obelisk 2
# Toki Underground 1
# Brasserie Beck 1
# Sakedokoro Makoto 1
# Proof 1
# Founding Farmers 1
# Flight Wine Bar 1
# Good Stuff Eatery 1
# Charlie Palmer Steak 1
# Burger Tap & Shake Foggy Bottom 1
# Al Dente Italian Restaurant D.C. 1
# Georgia Brown's Restaurant 1
# the pig 1
# Old Ebbitt Grill 1
# Boundary Stone 1
# Ben's Chili Bowl 1
# Clyde's of Georgetown 1
# Buck's Fishing & Camping 1
# Matisse 2
# The Grill Room 1
# Jack Rose Dining Saloon 1
# Pesce 1
# Acacia Bistro & Wine Bar 1
# Convivial 1
# Maketto 1
# Brasserie Beck 1
# Garrison 1
# Marcel’s 1

# %%
et = ExtraTreesClassifier()

# %%
score(et,"Extra Trees Classifier",X_scaled,y)
# Out:
# Extra Trees Classifier Score:	0.85 ± 0.02

# %%
fitAndPrint(et)
# Out:
# [[278  16   1]
#  [ 22   8   4]
#  [  4   1   5]]

# %%
predictions = gb.predict(X_scaled_dc)

# %%
count=0
for a,b in zip(dc["name"].values,predictions):
    if b>=1:
        print a,b
# Out:
# The Lafayette 2
# Marcel's 1
# Plume 2
# The Oval Room 1
# Al Tiramisu 1
# Komi 1
# Blue Duck Tavern 1
# 1789 Restaurant 1
# Obelisk 2
# Toki Underground 1
# Brasserie Beck 1
# Sakedokoro Makoto 1
# Proof 1
# Founding Farmers 1
# Flight Wine Bar 1
# Good Stuff Eatery 1
# Charlie Palmer Steak 1
# Burger Tap & Shake Foggy Bottom 1
# Al Dente Italian Restaurant D.C. 1
# Georgia Brown's Restaurant 1
# the pig 1
# Old Ebbitt Grill 1
# Boundary Stone 1
# Ben's Chili Bowl 1
# Clyde's of Georgetown 1
# Buck's Fishing & Camping 1
# Matisse 2
# The Grill Room 1
# Jack Rose Dining Saloon 1
# Pesce 1
# Acacia Bistro & Wine Bar 1
# Convivial 1
# Maketto 1
# Brasserie Beck 1
# Garrison 1
# Marcel’s 1

# %%
from sklearn.svm import SVC

# %%
sv = SVC(kernel="poly")

# %%
score(sv,"SVM",X_scaled,y)
# Out:
# SVM Score:	0.873 ± 0.009

# %%
fitAndPrint(sv)
# Out:
# [[282  13   0]
#  [ 20  12   2]
#  [  3   6   1]]

# %%
predictions = sv.predict(X_scaled_dc)

# %%
count=0
for a,b in zip(dc["name"].values,predictions):
    if b>=1:
        print a,b
# Out:
# Fogo de Chão Brazilian Steakhouse 1
# Minibar 1
# The Lafayette 1
# Marcel's 1
# Plume 1
# Komi 1
# Obelisk 2
# The Capital Grille 2
# Campono 2
# Founding Farmers 1
# Bub and Pop's 2
# Matisse 2
# Marcel’s 1

# %%
us_mg["zip"] = us_mg.address.apply(lambda x: x[-5:])

# %%
us_mg.to_csv("us_data.csv",encoding="utf-8",index=False)

# %%
us_mg
# Out:
#                              name  stars  \
# 0                  Noodle Pudding    0.0
# 1                     Peter Luger    1.0
# 2                          Gnocco    0.0
# 3                          Hasaki    0.0
# 4                          Hearth    0.0
# 5                        Kanoyama    0.0
# 6              Rocking Horse Cafe    0.0
# 7                         Paradou    0.0
# 8                          BONDST    0.0
# 9            Gotham Bar and Grill    1.0
# 11                       Le Gigot    0.0
# 12                           Lupa    0.0
# 13               Pearl Oyster Bar    0.0
# 14                 Phoenix Garden    0.0
# 15                  Dim Sum Go Go    0.0
# 16              Peking Duck House    0.0
# 17                          Babbo    1.0
# 18                         Crispo    0.0
# 19               Mary's Fish Camp    0.0
# 20            Nebraska Steakhouse    0.0
# 21                      Il Riccio    0.0
# 22                           JoJo    0.0
# 23                      Lusardi's    0.0
# 24                          Orsay    0.0
# 25              Shanghai Pavilion    0.0
# 26                        Aureole    1.0
# 28                    Café Boulud    1.0
# 29               Blue Water Grill    0.0
# 30                      Casa Mono    1.0
# 32                       Craftbar    0.0
# ...                           ...    ...
# 1054                Atelier Crenn    2.0
# 1056           Nom Wah Tea Parlor    0.0
# 1057                   El Mio Cid    0.0
# 1058                         Sura    0.0
# 1059                 Taci's Beyti    0.0
# 1060                   Uncle Zhou    0.0
# 1063                Lulu &amp; Po    0.0
# 1064    Bavette's Bar &amp; Boeuf    0.0
# 1065                Tortoise Club    0.0
# 1066                    Padrecito    0.0
# 1068                     Travelle    0.0
# 1069                    Larb Ubol    0.0
# 1070                 Morgan's BBQ    0.0
# 1071                        Tessa    0.0
# 1072                         Navy    0.0
# 1073    Russ &amp; Daughters Cafe    0.0
# 1074  Gregory's 26 Corner Taverna    0.0
# 1075                 The Progress    0.0
# 1077                        Aatxe    0.0
# 1079                 Lord Stanley    1.0
# 1081            Longbranch Saloon    0.0
# 1083                   Outerlands    0.0
# 1085                398 Brasserie    0.0
# 1087              Izakaya Rintaro    0.0
# 1089                   Al's Place    1.0
# 1091                      Paprika    0.0
# 1092                Los Cilantros    0.0
# 1094                  Staropolska    0.0
# 1095                    Charlatan    0.0
# 1096                 The Duck Inn    0.0
#
#                                                  review      cooking_type  \
# 0     With Dean Martin and Frank Sinatra rotating on...           Italian
# 1     Venerated Peter Luger resides in an expansive ...        Steakhouse
# 2     A casual cucina with a lovely back garden, Gno...           Italian
# 3     Since the mid-eighties, this local darling has...          Japanese
# 4     After more than a decade delighting fans, Chef...     Mediterranean
# 5     Offering an impressive lineup of excellent qua...          Japanese
# 6     A Chelsea classic since 1988, this Mexican caf...           Mexican
# 7     For a restaurant that refuses to take itself t...            French
# 8     There's no denying that BONDST is still trendy...          Japanese
# 9     Warm, personable, and genuine, Gotham Bar and ...          American
# 11    As classically beautiful and intricate as the ...            French
# 12    One of the best places for a solid plate of pa...           Italian
# 13    It's not hard to find a lobster roll in this c...           Seafood
# 14    This fuss-free and no-frills basement joint sh...           Chinese
# 15    This wildly popular dim sum joint is still pac...           Chinese
# 16    It's worth your while to wend through Chinatow...           Chinese
# 17    Is Mario Batali's beloved wild child of the fi...           Italian
# 18    Convivial Crispo is a breath of fresh, rustic ...           Italian
# 19    This West Village seafood shack is much more t...           Seafood
# 20    Marked by a relatively modest and discreet faç...        Steakhouse
# 21    Long-standing and low-key, this is just the ri...           Italian
# 22    Chef Jean-Georges Vongerichten's little neighb...      Contemporary
# 23    With its pumpkin-colored walls, dark woodwork,...           Italian
# 24    With its mahogany paneling, hand-laid mosaic t...            French
# 25    Polished Shanghai Pavilion offers plenty of ch...           Chinese
# 26    Nestled smack dab in the middle of the melee t...      Contemporary
# 28    Taking its cue from classic French cuisine, Da...            French
# 29    This New York institution has become an iconic...           Seafood
# 30    Casa Mono is tiny, jammed, and totally New Yor...           Spanish
# 32    Its ersatz industrial aesthetic and the rumble...      Contemporary
# ...                                                 ...               ...
# 1054  Neutral gray and very discreet, Atelier Crenn ...      Contemporary
# 1056  Even after a renovation, this "parlor" continu...           Chinese
# 1057  In contrast to popular tapas spots sweeping th...           Spanish
# 1058  Tucked in next to the Marrakech Hotel, Sura de...              Thai
# 1059  Find safety from the evil eye at Taci's Beyti,...           Turkish
# 1060  Gifted cooks have been setting up in Elmhurst ...           Chinese
# 1063  Nestled around the corner of an otherwise forg...          American
# 1064  Restaurateur Brendan Sokoloff (also of Maude's...          American
# 1065  Every city needs a restaurant with the word "c...          American
# 1066  Like its baby sib Mamacita, this easygoing can...           Mexican
# 1068  This contemporary Mediterranean dining room sh...     Mediterranean
# 1069  Chef Ratchanee Sumpatboon is cooking up her ow...              Thai
# 1070  Barbecue has been having a New York moment, mi...          Barbecue
# 1071  An industrial-inspired enoteca, Tessa makes a ...     Mediterranean
# 1072  Only Navy could pull off a nautical-themed res...           Seafood
# 1073  From white-jacketed servers to that pristine c...              Deli
# 1074  Judge a book by its cover and miss the rustic ...             Greek
# 1075  The sequel to mega-popular State Bird Provisio...      Contemporary
# 1077  The name is pronounced "ahh-chay" and the food...           Spanish
# 1079  You'll feast like a very refined lord at this ...       Californian
# 1081  The wonders of whiskey are on full display at ...         Gastropub
# 1083  For the residents of this foggy beachside comm...          American
# 1085  Skip the Union Square tourist traps and head f...            French
# 1087  Delicate izakaya cuisine with a produce-centri...          Japanese
# 1089  Fresh, seasonal vegetables and seafood headlin...       Californian
# 1091  Diners who set foot into Paprika, named for on...  Eastern European
# 1092  If there's no Mexican grandma in your life, Lo...           Mexican
# 1094  Fans of traditional Polish cooking know to pro...            Polish
# 1095  Despite what its moniker might suggest, Charla...     Mediterranean
# 1096  Grab a taxi and head to the warehouses of Brid...          American
#
#                                           address  usd_avg state  rating  \
# 0                    38 Henry St., New York 11201     37.0    NY     4.3
# 1                    178 Broadway, New York 11211    112.5    NY     4.2
# 2                 337 E. 10th St., New York 10009     37.0    NY     3.9
# 3                  210 E. 9th St., New York 10003     37.0    NY     4.2
# 4                 403 E. 12th St., New York 10009     62.0    NY     4.2
# 5                 175 Second Ave., New York 10003     37.0    NY     4.1
# 6                 182 Eighth Ave., New York 10011     37.0    NY     4.0
# 7            8 Little W. 12th St., New York 10014     37.0    NY     3.4
# 8                      6 Bond St., New York 10014     62.0    NY     4.2
# 9                  12 E. 12th St., New York 10003     62.0    NY     4.5
# 11                18 Cornelia St., New York 10014     37.0    NY     4.4
# 12               170 Thompson St., New York 10012     37.0    NY     4.2
# 13                18 Cornelia St., New York 10014     37.0    NY     4.3
# 14                242 E. 40th St., New York 10016     37.0    NY     3.7
# 15                5 East Broadway, New York 10038     37.0    NY     3.7
# 16                    28 Mott St., New York 10013     37.0    NY     3.8
# 17                110 Waverly Pl., New York 10011    112.5    NY     4.2
# 18                240 W. 14th St., New York 10011     37.0    NY     4.0
# 19                 64 Charles St., New York 10014     37.0    NY     4.1
# 20                   15 Stone St., New York 10004     62.0    NY     4.0
# 21                152 E. 79th St., New York 10021     37.0    NY     4.3
# 22                160 E. 64th St., New York 10021     62.0    NY     4.2
# 23               1494 Second Ave., New York 10021     62.0    NY     4.5
# 24            1057 Lexington Ave., New York 10021     37.0    NY     3.8
# 25                1378 Third Ave., New York 10021     37.0    NY     3.8
# 26                135 W. 42nd St., New York 10036    112.5    NY     4.4
# 28                 20 E. 76th St., New York 10021    112.5    NY     4.4
# 29              31 Union Sq. West, New York 10003     37.0    NY     4.1
# 30                  52 Irving Pl., New York 10003     62.0    NY     4.2
# 32                   900 Broadway, New York 10003     37.0    NY     3.9
# ...                                           ...      ...   ...     ...
# 1054       3127 Fillmore St., San Francisco 94123    112.5    CA     4.6
# 1056                13 Doyers St., New York 10013     18.5    NY     4.1
# 1057                 50 Starr St., Brooklyn 11221     37.0    NY     3.6
# 1058                2656 Broadway, New York 10025     18.5    NY     3.6
# 1059  1953-1955 Coney Island Ave., Brooklyn 11223     37.0    NY     4.4
# 1060               83-29 Broadway, Elmhurst 11373     18.5    NY     4.1
# 1063             154 Carlton Ave., Brooklyn 11205     37.0    NY     4.2
# 1064             218 W. Kinzie St., Chicago 60654     62.0    IL     4.6
# 1065              350 N. State St., Chicago 60654     62.0    IL     4.1
# 1066            901 Cole St., San Francisco 94117     37.0    CA     4.3
# 1068            330 N. Wabash Ave., Chicago 60611     62.0    IL     4.2
# 1069               480 Ninth Ave., New York 10018     18.5    NY     4.3
# 1070            267 Flatbush Ave., Brooklyn 11217     37.0    NY     4.2
# 1071           349 Amsterdam Ave., New York 10024     62.0    NY     4.3
# 1072             137 Sullivan St., New York 10012     37.0    NY     4.0
# 1073              127 Orchard St., New York 10002     37.0    NY     4.5
# 1074               26-02 23rd Ave., Astoria 11105     37.0    NY     4.4
# 1075       1525 Fillmore St., San Francisco 94115     62.0    CA     4.6
# 1077         2174 Market St., San Francisco 94114     37.0    CA     4.1
# 1079           2065 Polk St., San Francisco 94109     62.0    CA     4.2
# 1081          2512 San Pablo Ave., Berkeley 94702     37.0    CA     4.3
# 1083          4001 Judah St., San Francisco 94122     37.0    CA     4.3
# 1085           398 Geary St., San Francisco 94012     62.0    CA     3.2
# 1087             82 14th St., San Francisco 94103     37.0    CA     4.8
# 1089       1499 Valencia St., San Francisco 94110     37.0    CA     4.6
# 1091           3324 24th St., San Francisco 94110     18.5    CA     3.6
# 1092           3105 Shattuck Ave., Berkeley 94705     18.5    CA     4.0
# 1094        3030 N. Milwaukee Ave., Chicago 60618     18.5    IL     4.6
# 1095          1329 W. Chicago Ave., Chicago 60642     37.0    IL     4.2
# 1096           2701 S. Eleanor St., Chicago 60608     37.0    IL     4.2
#
#       numrev  goog_price  cuisine  bstars  cstars      pc    zip
# 0        118           2       54       0       0   37.00  11201
# 1        911           4       99       1       1  112.50  11211
# 2         72           2       82       0       0   37.00  10009
# 3         63           2       55       0       0   37.00  10003
# 4        102           3       32       0       0   87.25  10009
# 5         88           2       55       0       0   37.00  10003
# 6        137           2       66       0       0   37.00  10011
# 7         97           3       44       0       0   37.00  10014
# 8        131           3       55       0       0   62.00  10014
# 9        377           4        2       1       1  112.50  10003
# 11        43           2       44       0       0   37.00  10014
# 12       261           3       54       0       0   37.00  10012
# 13       136           3       91       0       0   37.00  10014
# 14        51           2       29       0       0   37.00  10016
# 15       174           2       29       0       0   37.00  10038
# 16       210           2       29       0       0   37.00  10013
# 17       487           4       54       1       1  112.50  10011
# 18       141           3       54       0       0   37.00  10011
# 19       107           2       91       0       0   37.00  10014
# 20        15           3       99       0       0   62.00  10004
# 21        15           3       54       0       0   37.00  10021
# 22       106           3       44       0       0   37.00  10021
# 23        35           3       54       0       0   37.00  10021
# 24        75           3       44       0       0   37.00  10021
# 25        21           2       29       0       0   37.00  10021
# 26       206           4        2       1       1  112.50  10036
# 28       180           4       44       1       1  112.50  10021
# 29       340           3       91       0       0   37.00  10003
# 30       192           3       98       1       1   37.00  10003
# 32       161           3       11       0       0   37.00  10003
# ...      ...         ...      ...     ...     ...     ...    ...
# 1054      83           4       44       1       2  112.50  94123
# 1056     273           2       29       0       0   37.00  10013
# 1057      29           2      100       0       0   37.00  11221
# 1058      28           2      101       0       0   37.00  10025
# 1059     176           2      102       0       0   37.00  11223
# 1060      24           1       29       0       0   18.50  11373
# 1063      14           2        2       0       0   37.00  11205
# 1064     128           3       99       0       0   62.00  60654
# 1065      41           3        2       0       0   37.00  60654
# 1066      95           1       66       0       0   18.50  94117
# 1068      18           3        2       0       0   37.00  60611
# 1069      82           1      101       0       0   18.50  10018
# 1070     143           1       12       0       0   27.75  11217
# 1071      36           2       65       0       0   37.00  10024
# 1072      17           2       91       0       0   37.00  10012
# 1073     162           2       57       0       0   37.00  10002
# 1074      25           2       86       0       0   37.00  11105
# 1075      65           4       23       0       0   62.00  94115
# 1077      35           3       98       0       0   37.00  94114
# 1079      26           4       41       1       1   62.00  94109
# 1081      29           2       23       0       0   37.00  94702
# 1083     235           2        2       0       0   37.00  94122
# 1085      35           4       44       0       0  112.50  94012
# 1087      56           3       55       0       0   62.00  94103
# 1089      76           2        2       1       1   37.00  94110
# 1091      23           2      103       0       0   18.50  94110
# 1092      12           1       66       0       0   18.50  94705
# 1094      87           2       84       0       0   18.50  60618
# 1095      29           2       54       0       0   37.00  60642
# 1096      44           2        2       0       0   37.00  60608
#
# [846 rows x 15 columns]
